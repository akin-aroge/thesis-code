# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

data_dir = r"C:\Users\Fabusuyi\Documents\Work _UCT\PG\Data\new_data\exp\my_data\data_fuelcon_random"  # change

# %%
plt.rcParams['figure.figsize'] = 4,3

# %%
def read_daq_data(data_dir, fname, columns=['time', 'value'], sep=' '):
    """this is a wrapper around the pd.read_csv to read my data format 
    from the fuel cell experiments
    
    params:
        data_dir: directory containing data
        fname: file_name
        columns: column names for the data
        sep: separator
    """
    
    
    data_path = os.path.join(os.path.normpath(data_dir), fname)
    
    return pd.read_csv(data_path, sep=sep, names=columns)
    
def plot_daq_data(df):
    fig, ax = plt.subplots()
    ax.plot(df['time'], df['value'])

# %% [markdown]
# ## step1

# %%
step1 = read_daq_data(data_dir, 'step1.csv')
step1.head()
# Out:
#     time     value
# 0  0.000  0.696727
# 1  0.001  0.697664
# 2  0.002  0.694852
# 3  0.003  0.694540
# 4  0.004  0.695164

# %%
#plt.plot(step1['time'], step1['value'])

# %%
step1['ck'] = step1['value'].values[::-1]
step1.head()
# Out:
#     time     value        ck
# 0  0.000  0.696727  0.587371
# 1  0.001  0.697664  0.590495
# 2  0.002  0.694852  0.590807
# 3  0.003  0.694540  0.589558
# 4  0.004  0.695164  0.590807

# %%
fig, ax = plt.subplots()
ax.plot(step1['time'], step1['ck'])
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %%
l = 0.0
r = 7.0

l_idx = step1.index[step1['time'] == l].tolist()[0]
r_idx = step1.index[step1['time'] == r].tolist()[0]
step1_ = step1.iloc[l_idx:r_idx, :]
step1_.head()

fig, ax = plt.subplots()
step1_['ck'].plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig, ax = plt.subplots()
ax.hist(step1_['ck'], bins=20);
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %% [markdown]
# ## step2

# %%
step2 = read_daq_data(data_dir, 'step2.csv')
step2.head()
# Out:
#     time     value
# 0  0.000  0.597369
# 1  0.001  0.597681
# 2  0.002  0.600181
# 3  0.003  0.599243
# 4  0.004  0.600493

# %%
fig, ax = plt.subplots()
ax.plot(step2['time'], step2['value'])
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %% [markdown]
# ## swing

# %%
swing = read_daq_data(data_dir, 'swing.csv')
swing.head()
# Out:
#     time     value
# 0  0.000  0.695477
# 1  0.001  0.696727
# 2  0.002  0.697039
# 3  0.003  0.696727
# 4  0.004  0.694852

# %%
plot_daq_data(swing)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %% [markdown]
# ## swing2

# %%
swing2 = read_daq_data(data_dir, 'swing2.csv')
swing2.head()
# Out:
#    time     value
# 0   0.0  0.768902
# 1   0.1  0.769214
# 2   0.2  0.770151
# 3   0.3  0.769527
# 4   0.4  0.769839

# %%
plot_daq_data(swing2)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %% [markdown]
# ## pre_eis1

# %%
pre_eis1 = read_daq_data(data_dir, 'pre_eis1.csv')
plot_daq_data(pre_eis1)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %% [markdown]
# ## pre_eis2

# %%
pre_eis2 = read_daq_data(data_dir, 'pre_eis2.csv')
plot_daq_data(pre_eis2)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %%
pre_eis3 = read_daq_data(data_dir, 'pre_eis3.csv')
plot_daq_data(pre_eis3)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %%
pre_eis3.head()
# Out:
#    time     value
# 0  0.00  0.808895
# 1  0.01  0.809207
# 2  0.02  0.808582
# 3  0.03  0.808895
# 4  0.04  0.810145
